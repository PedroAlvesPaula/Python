# %%
import requests
import json

# %%
cotacoes = requests.get("https://economia.awesomeapi.com.br/last/USD-BRL,EUR-BRL,BTC-BRL,BRL-USD")

cotacoes =  cotacoes.json()

# %%
with open(".//cotacoes.json", 'w') as file:
    json.dump(cotacoes, file, indent=2)
